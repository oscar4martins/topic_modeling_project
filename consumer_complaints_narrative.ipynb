# %% [markdown]
# ### Analysis On The Raw Complaints Text From the CFPB to Determine the Topics that Bank of America Customers Complain About Most.

# %%
#Dependencies
import csv
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %% [markdown]
# ### Data Exploration and Cleaning

# %%
#Importing the csv file
file = ('./CFPB-Data.csv')
df = pd.read_csv(file, encoding="iso-8859-1")
df
# Out:
#       Date received                  Product  \
# 0            3/4/17  Bank account or service
# 1           4/12/17  Bank account or service
# 2            3/4/17              Credit card
# 3           4/14/17                 Mortgage
# 4            4/8/17            Consumer Loan
# 5           3/31/17                 Mortgage
# 6            4/4/17  Bank account or service
# 7            4/5/17  Bank account or service
# 8           3/23/17            Consumer Loan
# 9           4/16/17  Bank account or service
# 10          3/31/17  Other financial service
# 11           4/5/17              Credit card
# 12           3/4/17              Credit card
# 13          4/14/17  Bank account or service
# 14           4/7/17  Bank account or service
# 15           4/6/17                 Mortgage
# 16          3/11/17            Consumer Loan
# 17          4/12/17  Bank account or service
# 18           3/5/17              Credit card
# 19          1/28/17             Prepaid card
# 20          4/14/17              Credit card
# 21         11/30/16                 Mortgage
# 22           4/4/17                 Mortgage
# 23           3/5/17            Consumer Loan
# 24           4/3/17                 Mortgage
# 25           4/8/17  Bank account or service
# 26          3/31/17  Bank account or service
# 27          3/21/17  Bank account or service
# 28           4/7/17  Bank account or service
# 29          3/31/17                 Mortgage
# ...             ...                      ...
# 35867        7/2/16              Credit card
# 35868       6/24/15              Credit card
# 35869        9/5/15              Credit card
# 35870       9/13/16                 Mortgage
# 35871      10/30/15              Credit card
# 35872      12/13/15            Consumer Loan
# 35873      12/22/15              Credit card
# 35874      12/31/15                 Mortgage
# 35875       5/20/15          Debt collection
# 35876       6/14/16            Consumer Loan
# 35877       1/15/17             Student loan
# 35878       6/11/16  Bank account or service
# 35879       6/23/16  Bank account or service
# 35880       11/2/16  Bank account or service
# 35881       9/20/16              Credit card
# 35882       2/12/16                 Mortgage
# 35883       7/22/15          Debt collection
# 35884        9/7/16  Bank account or service
# 35885       5/11/15              Credit card
# 35886       10/4/16             Student loan
# 35887       6/18/16                 Mortgage
# 35888       10/4/15              Credit card
# 35889       1/11/17              Credit card
# 35890       9/27/16             Student loan
# 35891        7/6/15            Consumer Loan
# 35892       8/29/15                 Mortgage
# 35893       8/26/15  Bank account or service
# 35894        1/2/17              Credit card
# 35895       1/19/16              Credit card
# 35896       1/30/16  Bank account or service
#
#                                   Sub-product  \
# 0                            Checking account
# 1                            Checking account
# 2                                         NaN
# 3                 Conventional fixed mortgage
# 4                               Vehicle lease
# 5          Home equity loan or line of credit
# 6                            Checking account
# 7                             Savings account
# 8                                   Pawn loan
# 9                            Checking account
# 10                                Money order
# 11                                        NaN
# 12                                        NaN
# 13                           Checking account
# 14                           Checking account
# 15                               FHA mortgage
# 16                           Installment loan
# 17                           Checking account
# 18                                        NaN
# 19                       General purpose card
# 20                                        NaN
# 21     Conventional adjustable mortgage (ARM)
# 22                                VA mortgage
# 23                               Vehicle loan
# 24                Conventional fixed mortgage
# 25                           Checking account
# 26                 Other bank product/service
# 27                           Checking account
# 28                           Checking account
# 29                             Other mortgage
# ...                                       ...
# 35867                                     NaN
# 35868                                     NaN
# 35869                                     NaN
# 35870             Conventional fixed mortgage
# 35871                                     NaN
# 35872                            Vehicle loan
# 35873                                     NaN
# 35874  Conventional adjustable mortgage (ARM)
# 35875                                Mortgage
# 35876                           Vehicle lease
# 35877          Federal student loan servicing
# 35878              Other bank product/service
# 35879                        Checking account
# 35880                        Checking account
# 35881                                     NaN
# 35882             Conventional fixed mortgage
# 35883                             Credit card
# 35884                        Checking account
# 35885                                     NaN
# 35886                Non-federal student loan
# 35887      Home equity loan or line of credit
# 35888                                     NaN
# 35889                                     NaN
# 35890                Non-federal student loan
# 35891                            Vehicle loan
# 35892  Conventional adjustable mortgage (ARM)
# 35893                        Checking account
# 35894                                     NaN
# 35895                                     NaN
# 35896                         Savings account
#
#                                           Issue  \
# 0       Account opening, closing, or management
# 1         Problems caused by my funds being low
# 2                              Balance transfer
# 3      Loan servicing, payments, escrow account
# 4                  Taking out the loan or lease
# 5      Loan servicing, payments, escrow account
# 6      Making/receiving payments, sending money
# 7       Account opening, closing, or management
# 8        Applied for loan/did not receive money
# 9       Account opening, closing, or management
# 10                   Lost or stolen money order
# 11        Identity theft / Fraud / Embezzlement
# 12                               Payoff process
# 13      Account opening, closing, or management
# 14                     Deposits and withdrawals
# 15     Loan modification,collection,foreclosure
# 16                 Taking out the loan or lease
# 17      Account opening, closing, or management
# 18                   Closing/Cancelling account
# 19        Managing, opening, or closing account
# 20                               Payoff process
# 21     Loan servicing, payments, escrow account
# 22                 Settlement process and costs
# 23                   Managing the loan or lease
# 24     Application, originator, mortgage broker
# 25      Account opening, closing, or management
# 26      Account opening, closing, or management
# 27      Account opening, closing, or management
# 28      Account opening, closing, or management
# 29                 Settlement process and costs
# ...                                         ...
# 35867                        Delinquent account
# 35868                          Billing disputes
# 35869                              Cash advance
# 35870  Loan modification,collection,foreclosure
# 35871                          Billing disputes
# 35872       Problems when you are unable to pay
# 35873                         Billing statement
# 35874  Loan modification,collection,foreclosure
# 35875        False statements or representation
# 35876                Managing the loan or lease
# 35877        Dealing with my lender or servicer
# 35878  Making/receiving payments, sending money
# 35879     Problems caused by my funds being low
# 35880     Problems caused by my funds being low
# 35881                         Transaction issue
# 35882            Credit decision / Underwriting
# 35883           Disclosure verification of debt
# 35884   Account opening, closing, or management
# 35885                          Billing disputes
# 35886        Dealing with my lender or servicer
# 35887  Application, originator, mortgage broker
# 35888                          Billing disputes
# 35889              Application processing delay
# 35890        Dealing with my lender or servicer
# 35891              Taking out the loan or lease
# 35892  Loan modification,collection,foreclosure
# 35893                  Deposits and withdrawals
# 35894  Credit card protection / Debt protection
# 35895                 Advertising and marketing
# 35896  Making/receiving payments, sending money
#
#                                    Sub-issue  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15                                       NaN
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# ...                                      ...
# 35867                                    NaN
# 35868                                    NaN
# 35869                                    NaN
# 35870                                    NaN
# 35871                                    NaN
# 35872                                    NaN
# 35873                                    NaN
# 35874                                    NaN
# 35875   Impersonated an attorney or official
# 35876                                    NaN
# 35877  Trouble with how payments are handled
# 35878                                    NaN
# 35879                                    NaN
# 35880                                    NaN
# 35881                                    NaN
# 35882                                    NaN
# 35883   Not given enough info to verify debt
# 35884                                    NaN
# 35885                                    NaN
# 35886          Don't agree with fees charged
# 35887                                    NaN
# 35888                                    NaN
# 35889                                    NaN
# 35890  Trouble with how payments are handled
# 35891                                    NaN
# 35892                                    NaN
# 35893                                    NaN
# 35894                                    NaN
# 35895                                    NaN
# 35896                                    NaN
#
#                             Consumer complaint narrative  \
# 0      My wife and I visited the Chase Bank branch at...
# 1      I have documentation that shows that US Bank w...
# 2      Around XX/XX/XXXX I accepted a credit card off...
# 3      Regarding PMI : we paid up front at closing to...
# 4      I have leased a vehicle XX/XX/2015 from an aut...
# 5      In XX/XX/2005 I obtained a home equity mortgag...
# 6      I have been deprived of my income as Bank of A...
# 7      Ally Bank turned me down for deceased relative...
# 8      Several years ago I got a line of credit loan ...
# 9      I submitted a complaint in XX/XX/XXXX regardin...
# 10     I bought a money order from XXXX XXXX to pay a...
# 11     My business debit cards were stolen from my ma...
# 12     I have paid the entire balance off of this car...
# 13     I have opened the account of Bank of America a...
# 14     Sent an electronic message to Ally customer se...
# 15     I do not feel I 've been getting fair opportun...
# 16     On behalf of my dad XXXX who is XXXX years of ...
# 17     On XX/XX/XXXX our XXXX of XXXX.. passed away. ...
# 18     Opened credit card with Chase Business Ink cre...
# 19     I have a Wells Fargo credit card, and when I c...
# 20     I entered into a settlement agreement with Ban...
# 21     I have an outstanding issue which suntrust has...
# 22     Bank of America, N.A., Fraudulent collection a...
# 23     I had a vehicle loan that was opened by a deal...
# 24     About a month ago, My wife and I submitted an ...
# 25     Bank of America commits felony by using fictit...
# 26     The representatives of XXXX went to Wells Farg...
# 27     AFTER NUMEROUS COMPLAINTS,, BANK OF AMERICA RE...
# 28     Bank of America committs felony and owes me XX...
# 29     I have been a victim of fraud. Back in XX/XX/X...
# ...                                                  ...
# 35867  **NEW INFORMATION** DUNNING LETTER DATED XX/XX...
# 35868  I have been paying my Dillard 's credit card o...
# 35869  I have had a credit card with Chase for 6 year...
# 35870  On XXXX XXXX, 2015 at XXXX I was served with a...
# 35871  New Credit Card. A charge for {$75.00} was on ...
# 35872  Wells Fargo Dealer Services repossessed my veh...
# 35873  I have been a customer of citi cards for some ...
# 35874  I filed a previous complaint on XXXX/XXXX/XXXX...
# 35875  XXXX Bank XXXX is the substitutionary plaintif...
# 35876  yes i have a car loan out with ally.on my cred...
# 35877  I will need to send you the information becaus...
# 35878  I provide more supporting documents for the fo...
# 35879  I went into the branch of Chase Bank and reque...
# 35880  PNC banking institution used questionable tact...
# 35881  I made a charge with my Bank of America credit...
# 35882  Regions Mortgage is reported wage earner on cr...
# 35883  TDBAnk/ Target refused to accept credit counse...
# 35884  Where to start, I had mixed a debit card up wi...
# 35885  I purchased a brand new XXXX, side by side, re...
# 35886  After many months, or years, of having private...
# 35887  Complaint to CFPB regarding Chase letter offer...
# 35888  XXXX refuses to to refund my money which comes...
# 35889  Amazon said I would get {$50.00} if I applied ...
# 35890  My daughter took out a private student loan tw...
# 35891  In XX/XX/XXXX my mother and I purchased a XX/X...
# 35892  I have applied for loan modification with Bank...
# 35893  I wrote XXXX checks from my credit union check...
# 35894  I signed up for a Macy 's credit card in XXXX ...
# 35895  I took out a XXXX Chase credit card. The card ...
# 35896  On XXXX XXXX, 2016 at around XXXX, I submitted...
#
#                                  Company public response  \
# 0                                                    NaN
# 1      Company has responded to the consumer and the ...
# 2                                                    NaN
# 3      Company has responded to the consumer and the ...
# 4      Company has responded to the consumer and the ...
# 5      Company has responded to the consumer and the ...
# 6      Company has responded to the consumer and the ...
# 7      Company has responded to the consumer and the ...
# 8      Company has responded to the consumer and the ...
# 9      Company has responded to the consumer and the ...
# 10     Company has responded to the consumer and the ...
# 11     Company has responded to the consumer and the ...
# 12                                                   NaN
# 13     Company has responded to the consumer and the ...
# 14     Company has responded to the consumer and the ...
# 15     Company has responded to the consumer and the ...
# 16     Company has responded to the consumer and the ...
# 17     Company has responded to the consumer and the ...
# 18                                                   NaN
# 19     Company has responded to the consumer and the ...
# 20     Company has responded to the consumer and the ...
# 21     Company has responded to the consumer and the ...
# 22     Company has responded to the consumer and the ...
# 23                                                   NaN
# 24     Company has responded to the consumer and the ...
# 25     Company has responded to the consumer and the ...
# 26     Company has responded to the consumer and the ...
# 27     Company has responded to the consumer and the ...
# 28     Company has responded to the consumer and the ...
# 29     Company has responded to the consumer and the ...
# ...                                                  ...
# 35867  Company has responded to the consumer and the ...
# 35868   Company chooses not to provide a public response
# 35869                                                NaN
# 35870  Company has responded to the consumer and the ...
# 35871   Company chooses not to provide a public response
# 35872   Company chooses not to provide a public response
# 35873   Company chooses not to provide a public response
# 35874   Company chooses not to provide a public response
# 35875                                                NaN
# 35876  Company has responded to the consumer and the ...
# 35877  Company has responded to the consumer and the ...
# 35878  Company has responded to the consumer and the ...
# 35879                                                NaN
# 35880                                                NaN
# 35881  Company has responded to the consumer and the ...
# 35882  Company has responded to the consumer and the ...
# 35883                                                NaN
# 35884                                                NaN
# 35885   Company chooses not to provide a public response
# 35886                                                NaN
# 35887                                                NaN
# 35888                                                NaN
# 35889                                                NaN
# 35890  Company has responded to the consumer and the ...
# 35891                                                NaN
# 35892   Company chooses not to provide a public response
# 35893   Company chooses not to provide a public response
# 35894  Company has responded to the consumer and the ...
# 35895                                                NaN
# 35896   Company chooses not to provide a public response
#
#                                       Company State ZIP code            Tags  \
# 0                        JPMORGAN CHASE & CO.    KY    423XX             NaN
# 1                                U.S. BANCORP    CA    928XX             NaN
# 2                        JPMORGAN CHASE & CO.    TN    376XX  Older American
# 3      WELLS FARGO BANK, NATIONAL ASSOCIATION    TX    750XX             NaN
# 4                         ALLY FINANCIAL INC.    CA    926XX             NaN
# 5       BANK OF AMERICA, NATIONAL ASSOCIATION    MP    554XX             NaN
# 6       BANK OF AMERICA, NATIONAL ASSOCIATION    MA    024XX             NaN
# 7                         ALLY FINANCIAL INC.    IL    600XX             NaN
# 8      WELLS FARGO BANK, NATIONAL ASSOCIATION    PA    182XX   Servicemember
# 9                                U.S. BANCORP    WI    532XX             NaN
# 10      BANK OF AMERICA, NATIONAL ASSOCIATION    NY    100XX             NaN
# 11      BANK OF AMERICA, NATIONAL ASSOCIATION    CA    958XX             NaN
# 12                       JPMORGAN CHASE & CO.    NJ    087XX  Older American
# 13      BANK OF AMERICA, NATIONAL ASSOCIATION    GA    300XX             NaN
# 14                        ALLY FINANCIAL INC.    IL    600XX             NaN
# 15     WELLS FARGO BANK, NATIONAL ASSOCIATION    MD    207XX             NaN
# 16     WELLS FARGO BANK, NATIONAL ASSOCIATION    NJ    086XX             NaN
# 17     WELLS FARGO BANK, NATIONAL ASSOCIATION    MD    206XX             NaN
# 18                       JPMORGAN CHASE & CO.    MN    553XX             NaN
# 19     WELLS FARGO BANK, NATIONAL ASSOCIATION   NaN      NaN  Older American
# 20      BANK OF AMERICA, NATIONAL ASSOCIATION    NC    275XX             NaN
# 21                       SUNTRUST BANKS, INC.    UT    840XX             NaN
# 22      BANK OF AMERICA, NATIONAL ASSOCIATION    WA    985XX   Servicemember
# 23                       JPMORGAN CHASE & CO.    IL    606XX             NaN
# 24     WELLS FARGO BANK, NATIONAL ASSOCIATION    NY    112XX             NaN
# 25      BANK OF AMERICA, NATIONAL ASSOCIATION    FL    330XX             NaN
# 26     WELLS FARGO BANK, NATIONAL ASSOCIATION    TN    373XX             NaN
# 27      BANK OF AMERICA, NATIONAL ASSOCIATION    FL    330XX             NaN
# 28      BANK OF AMERICA, NATIONAL ASSOCIATION    FL    330XX             NaN
# 29     WELLS FARGO BANK, NATIONAL ASSOCIATION    NJ    070XX             NaN
# ...                                       ...   ...      ...             ...
# 35867  WELLS FARGO BANK, NATIONAL ASSOCIATION    CA    956XX             NaN
# 35868  WELLS FARGO BANK, NATIONAL ASSOCIATION    FL    334XX             NaN
# 35869                    JPMORGAN CHASE & CO.    FL    339XX             NaN
# 35870  WELLS FARGO BANK, NATIONAL ASSOCIATION    FL    346XX             NaN
# 35871                          CITIBANK, N.A.    CA    945XX             NaN
# 35872  WELLS FARGO BANK, NATIONAL ASSOCIATION    TX    750XX             NaN
# 35873                          CITIBANK, N.A.    SC    295XX  Older American
# 35874  WELLS FARGO BANK, NATIONAL ASSOCIATION    CA    945XX             NaN
# 35875                    JPMORGAN CHASE & CO.    GA    315XX             NaN
# 35876                     ALLY FINANCIAL INC.    OH    444XX             NaN
# 35877  WELLS FARGO BANK, NATIONAL ASSOCIATION    TX    781XX   Servicemember
# 35878   BANK OF AMERICA, NATIONAL ASSOCIATION    CA    921XX             NaN
# 35879                    JPMORGAN CHASE & CO.    FL    336XX             NaN
# 35880                           PNC Bank N.A.    FL    333XX             NaN
# 35881   BANK OF AMERICA, NATIONAL ASSOCIATION    WA    988XX   Servicemember
# 35882                            REGIONS BANK    TN    380XX             NaN
# 35883              TD BANK US HOLDING COMPANY    MA    011XX             NaN
# 35884                    JPMORGAN CHASE & CO.    OH    433XX             NaN
# 35885                          CITIBANK, N.A.    FL    324XX             NaN
# 35886                    JPMORGAN CHASE & CO.    NY    130XX             NaN
# 35887                    JPMORGAN CHASE & CO.    NY    105XX  Older American
# 35888                    JPMORGAN CHASE & CO.    OH    446XX  Older American
# 35889                    JPMORGAN CHASE & CO.    TX    773XX  Older American
# 35890  WELLS FARGO BANK, NATIONAL ASSOCIATION    FL    342XX             NaN
# 35891       FIFTH THIRD FINANCIAL CORPORATION    NY    145XX  Older American
# 35892   BANK OF AMERICA, NATIONAL ASSOCIATION    MO    641XX             NaN
# 35893                            REGIONS BANK    GA    303XX             NaN
# 35894                          CITIBANK, N.A.    CA    941XX             NaN
# 35895                    JPMORGAN CHASE & CO.    NY    110XX             NaN
# 35896                     ALLY FINANCIAL INC.    NJ    080XX  Older American
#
#       Consumer consent provided? Submitted via Date sent to company  \
# 0               Consent provided           Web               3/4/17
# 1               Consent provided           Web              4/12/17
# 2               Consent provided           Web               3/4/17
# 3               Consent provided           Web              4/14/17
# 4               Consent provided           Web               4/8/17
# 5               Consent provided           Web               4/3/17
# 6               Consent provided           Web               4/4/17
# 7               Consent provided           Web               4/5/17
# 8               Consent provided           Web              3/23/17
# 9               Consent provided           Web              4/16/17
# 10              Consent provided           Web               4/3/17
# 11              Consent provided           Web               4/5/17
# 12              Consent provided           Web               3/4/17
# 13              Consent provided           Web              4/14/17
# 14              Consent provided           Web               4/7/17
# 15              Consent provided           Web               4/6/17
# 16              Consent provided           Web              3/14/17
# 17              Consent provided           Web              4/13/17
# 18              Consent provided           Web               3/5/17
# 19              Consent provided           Web               3/7/17
# 20              Consent provided           Web              4/14/17
# 21              Consent provided           Web             11/30/16
# 22              Consent provided           Web               4/4/17
# 23              Consent provided           Web               3/5/17
# 24              Consent provided           Web               4/3/17
# 25              Consent provided           Web               4/8/17
# 26              Consent provided           Web              3/31/17
# 27              Consent provided           Web              3/21/17
# 28              Consent provided           Web               4/7/17
# 29              Consent provided           Web              3/31/17
# ...                          ...           ...                  ...
# 35867           Consent provided           Web               7/2/16
# 35868           Consent provided           Web              6/29/15
# 35869           Consent provided           Web               9/5/15
# 35870           Consent provided           Web              9/13/16
# 35871           Consent provided           Web              11/4/15
# 35872           Consent provided           Web             12/13/15
# 35873           Consent provided           Web             12/22/15
# 35874           Consent provided           Web             12/31/15
# 35875           Consent provided           Web              5/20/15
# 35876           Consent provided           Web              6/14/16
# 35877           Consent provided           Web              1/15/17
# 35878           Consent provided           Web              6/11/16
# 35879           Consent provided           Web              6/23/16
# 35880           Consent provided           Web              11/2/16
# 35881           Consent provided           Web              9/20/16
# 35882           Consent provided           Web              2/18/16
# 35883           Consent provided           Web              7/22/15
# 35884           Consent provided           Web               9/7/16
# 35885           Consent provided           Web              5/12/15
# 35886           Consent provided           Web              10/4/16
# 35887           Consent provided           Web              6/20/16
# 35888           Consent provided           Web              10/4/15
# 35889           Consent provided           Web              1/11/17
# 35890           Consent provided           Web              9/30/16
# 35891           Consent provided           Web              7/13/15
# 35892           Consent provided           Web              8/29/15
# 35893           Consent provided           Web              8/26/15
# 35894           Consent provided           Web               1/2/17
# 35895           Consent provided           Web              1/19/16
# 35896           Consent provided           Web              1/30/16
#
#           Company response to consumer Timely response? Consumer disputed?  \
# 0              Closed with explanation              Yes                Yes
# 1              Closed with explanation              Yes                 No
# 2          Closed with monetary relief              Yes                 No
# 3              Closed with explanation              Yes                 No
# 4              Closed with explanation              Yes                 No
# 5              Closed with explanation              Yes                 No
# 6              Closed with explanation              Yes                 No
# 7              Closed with explanation              Yes                 No
# 8              Closed with explanation              Yes                 No
# 9      Closed with non-monetary relief              Yes                 No
# 10             Closed with explanation              Yes                 No
# 11         Closed with monetary relief              Yes                 No
# 12     Closed with non-monetary relief              Yes                 No
# 13         Closed with monetary relief              Yes                 No
# 14             Closed with explanation              Yes                 No
# 15             Closed with explanation              Yes                 No
# 16             Closed with explanation              Yes                 No
# 17             Closed with explanation              Yes                 No
# 18             Closed with explanation              Yes                 No
# 19             Closed with explanation              Yes                 No
# 20     Closed with non-monetary relief              Yes                 No
# 21             Closed with explanation              Yes                 No
# 22             Closed with explanation              Yes                 No
# 23             Closed with explanation              Yes                Yes
# 24             Closed with explanation              Yes                 No
# 25             Closed with explanation              Yes                 No
# 26             Closed with explanation               No                 No
# 27             Closed with explanation              Yes                 No
# 28             Closed with explanation              Yes                 No
# 29             Closed with explanation              Yes                 No
# ...                                ...              ...                ...
# 35867          Closed with explanation              Yes                Yes
# 35868      Closed with monetary relief              Yes                 No
# 35869          Closed with explanation              Yes                Yes
# 35870          Closed with explanation              Yes                Yes
# 35871  Closed with non-monetary relief              Yes                 No
# 35872  Closed with non-monetary relief              Yes                 No
# 35873          Closed with explanation              Yes                Yes
# 35874          Closed with explanation              Yes                 No
# 35875          Closed with explanation              Yes                Yes
# 35876          Closed with explanation              Yes                 No
# 35877          Closed with explanation               No                 No
# 35878          Closed with explanation              Yes                 No
# 35879      Closed with monetary relief              Yes                 No
# 35880          Closed with explanation              Yes                 No
# 35881          Closed with explanation              Yes                 No
# 35882          Closed with explanation              Yes                Yes
# 35883          Closed with explanation              Yes                Yes
# 35884  Closed with non-monetary relief              Yes                 No
# 35885          Closed with explanation              Yes                Yes
# 35886          Closed with explanation              Yes                Yes
# 35887          Closed with explanation              Yes                Yes
# 35888          Closed with explanation              Yes                 No
# 35889          Closed with explanation              Yes                Yes
# 35890          Closed with explanation              Yes                 No
# 35891          Closed with explanation              Yes                 No
# 35892          Closed with explanation              Yes                Yes
# 35893      Closed with monetary relief              Yes                 No
# 35894      Closed with monetary relief              Yes                 No
# 35895          Closed with explanation              Yes                Yes
# 35896          Closed with explanation              Yes                 No
#
#        Complaint ID
# 0           2371744
# 1           2431565
# 2           2371616
# 3           2436277
# 4           2426136
# 5           2412732
# 6           2419713
# 7           2420825
# 8           2401871
# 9           2437217
# 10          2412744
# 11          2420310
# 12          2371956
# 13          2436309
# 14          2424250
# 15          2420235
# 16          2382679
# 17          2430838
# 18          2372334
# 19          2315900
# 20          2436524
# 21          2226859
# 22          2418075
# 23          2371663
# 24          2417341
# 25          2426028
# 26          2412799
# 27          2397145
# 28          2425794
# 29          2413184
# ...             ...
# 35867       1996210
# 35868       1435163
# 35869       1553781
# 35870       2110060
# 35871       1633857
# 35872       1695113
# 35873       1713407
# 35874       1724444
# 35875       1384484
# 35876       1968906
# 35877       2290479
# 35878       1964097
# 35879       1982766
# 35880       2190798
# 35881       2122711
# 35882       1785745
# 35883       1480370
# 35884       2099955
# 35885       1368839
# 35886       2144622
# 35887       1974883
# 35888       1591932
# 35889       2284175
# 35890       2134811
# 35891       1451688
# 35892       1543504
# 35893       1538642
# 35894       2271373
# 35895       1746558
# 35896       1765398
#
# [35897 rows x 18 columns]

# %%
#Checking the shape of the data
df.shape
# Out:
# (35897, 18)

# %%
# to view the columns and the corresponding data types in each column, use the enumerate function:
for index, (name, dtype) in enumerate(zip(df.columns, df.dtypes)):
    print('{}.{}({})'.format(index,name,dtype))
# Out:
# 0.Date received(object)
# 1.Product(object)
# 2.Sub-product(object)
# 3.Issue(object)
# 4.Sub-issue(object)
# 5.Consumer complaint narrative(object)
# 6.Company public response(object)
# 7.Company(object)
# 8.State(object)
# 9.ZIP code(object)
# 10.Tags(object)
# 11.Consumer consent provided?(object)
# 12.Submitted via(object)
# 13.Date sent to company(object)
# 14.Company response to consumer(object)
# 15.Timely response?(object)
# 16.Consumer disputed?(object)
# 17.Complaint ID(int64)

# %%
#Renamed two columns from the data frame
df_new = df.rename(columns={'Date received':'Date_received',
                            'Consumer complaint narrative':'Consumer_complaint_narrative'})

# %%
df_new.head()
# Out:
#   Date_received                  Product                  Sub-product  \
# 0        3/4/17  Bank account or service             Checking account
# 1       4/12/17  Bank account or service             Checking account
# 2        3/4/17              Credit card                          NaN
# 3       4/14/17                 Mortgage  Conventional fixed mortgage
# 4        4/8/17            Consumer Loan                Vehicle lease
#
#                                       Issue Sub-issue  \
# 0   Account opening, closing, or management       NaN
# 1     Problems caused by my funds being low       NaN
# 2                          Balance transfer       NaN
# 3  Loan servicing, payments, escrow account       NaN
# 4              Taking out the loan or lease       NaN
#
#                         Consumer_complaint_narrative  \
# 0  My wife and I visited the Chase Bank branch at...
# 1  I have documentation that shows that US Bank w...
# 2  Around XX/XX/XXXX I accepted a credit card off...
# 3  Regarding PMI : we paid up front at closing to...
# 4  I have leased a vehicle XX/XX/2015 from an aut...
#
#                              Company public response  \
# 0                                                NaN
# 1  Company has responded to the consumer and the ...
# 2                                                NaN
# 3  Company has responded to the consumer and the ...
# 4  Company has responded to the consumer and the ...
#
#                                   Company State ZIP code            Tags  \
# 0                    JPMORGAN CHASE & CO.    KY    423XX             NaN
# 1                            U.S. BANCORP    CA    928XX             NaN
# 2                    JPMORGAN CHASE & CO.    TN    376XX  Older American
# 3  WELLS FARGO BANK, NATIONAL ASSOCIATION    TX    750XX             NaN
# 4                     ALLY FINANCIAL INC.    CA    926XX             NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web               3/4/17
# 1           Consent provided           Web              4/12/17
# 2           Consent provided           Web               3/4/17
# 3           Consent provided           Web              4/14/17
# 4           Consent provided           Web               4/8/17
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                Yes
# 1      Closed with explanation              Yes                 No
# 2  Closed with monetary relief              Yes                 No
# 3      Closed with explanation              Yes                 No
# 4      Closed with explanation              Yes                 No
#
#    Complaint ID
# 0       2371744
# 1       2431565
# 2       2371616
# 3       2436277
# 4       2426136

# %%
#Create a subset of the dataframe with varibles of interest
df_new_sub = df_new[['Date_received','Product','Consumer_complaint_narrative','Company']]
df_new_sub
# Out:
#       Date_received                  Product  \
# 0            3/4/17  Bank account or service
# 1           4/12/17  Bank account or service
# 2            3/4/17              Credit card
# 3           4/14/17                 Mortgage
# 4            4/8/17            Consumer Loan
# 5           3/31/17                 Mortgage
# 6            4/4/17  Bank account or service
# 7            4/5/17  Bank account or service
# 8           3/23/17            Consumer Loan
# 9           4/16/17  Bank account or service
# 10          3/31/17  Other financial service
# 11           4/5/17              Credit card
# 12           3/4/17              Credit card
# 13          4/14/17  Bank account or service
# 14           4/7/17  Bank account or service
# 15           4/6/17                 Mortgage
# 16          3/11/17            Consumer Loan
# 17          4/12/17  Bank account or service
# 18           3/5/17              Credit card
# 19          1/28/17             Prepaid card
# 20          4/14/17              Credit card
# 21         11/30/16                 Mortgage
# 22           4/4/17                 Mortgage
# 23           3/5/17            Consumer Loan
# 24           4/3/17                 Mortgage
# 25           4/8/17  Bank account or service
# 26          3/31/17  Bank account or service
# 27          3/21/17  Bank account or service
# 28           4/7/17  Bank account or service
# 29          3/31/17                 Mortgage
# ...             ...                      ...
# 35867        7/2/16              Credit card
# 35868       6/24/15              Credit card
# 35869        9/5/15              Credit card
# 35870       9/13/16                 Mortgage
# 35871      10/30/15              Credit card
# 35872      12/13/15            Consumer Loan
# 35873      12/22/15              Credit card
# 35874      12/31/15                 Mortgage
# 35875       5/20/15          Debt collection
# 35876       6/14/16            Consumer Loan
# 35877       1/15/17             Student loan
# 35878       6/11/16  Bank account or service
# 35879       6/23/16  Bank account or service
# 35880       11/2/16  Bank account or service
# 35881       9/20/16              Credit card
# 35882       2/12/16                 Mortgage
# 35883       7/22/15          Debt collection
# 35884        9/7/16  Bank account or service
# 35885       5/11/15              Credit card
# 35886       10/4/16             Student loan
# 35887       6/18/16                 Mortgage
# 35888       10/4/15              Credit card
# 35889       1/11/17              Credit card
# 35890       9/27/16             Student loan
# 35891        7/6/15            Consumer Loan
# 35892       8/29/15                 Mortgage
# 35893       8/26/15  Bank account or service
# 35894        1/2/17              Credit card
# 35895       1/19/16              Credit card
# 35896       1/30/16  Bank account or service
#
#                             Consumer_complaint_narrative  \
# 0      My wife and I visited the Chase Bank branch at...
# 1      I have documentation that shows that US Bank w...
# 2      Around XX/XX/XXXX I accepted a credit card off...
# 3      Regarding PMI : we paid up front at closing to...
# 4      I have leased a vehicle XX/XX/2015 from an aut...
# 5      In XX/XX/2005 I obtained a home equity mortgag...
# 6      I have been deprived of my income as Bank of A...
# 7      Ally Bank turned me down for deceased relative...
# 8      Several years ago I got a line of credit loan ...
# 9      I submitted a complaint in XX/XX/XXXX regardin...
# 10     I bought a money order from XXXX XXXX to pay a...
# 11     My business debit cards were stolen from my ma...
# 12     I have paid the entire balance off of this car...
# 13     I have opened the account of Bank of America a...
# 14     Sent an electronic message to Ally customer se...
# 15     I do not feel I 've been getting fair opportun...
# 16     On behalf of my dad XXXX who is XXXX years of ...
# 17     On XX/XX/XXXX our XXXX of XXXX.. passed away. ...
# 18     Opened credit card with Chase Business Ink cre...
# 19     I have a Wells Fargo credit card, and when I c...
# 20     I entered into a settlement agreement with Ban...
# 21     I have an outstanding issue which suntrust has...
# 22     Bank of America, N.A., Fraudulent collection a...
# 23     I had a vehicle loan that was opened by a deal...
# 24     About a month ago, My wife and I submitted an ...
# 25     Bank of America commits felony by using fictit...
# 26     The representatives of XXXX went to Wells Farg...
# 27     AFTER NUMEROUS COMPLAINTS,, BANK OF AMERICA RE...
# 28     Bank of America committs felony and owes me XX...
# 29     I have been a victim of fraud. Back in XX/XX/X...
# ...                                                  ...
# 35867  **NEW INFORMATION** DUNNING LETTER DATED XX/XX...
# 35868  I have been paying my Dillard 's credit card o...
# 35869  I have had a credit card with Chase for 6 year...
# 35870  On XXXX XXXX, 2015 at XXXX I was served with a...
# 35871  New Credit Card. A charge for {$75.00} was on ...
# 35872  Wells Fargo Dealer Services repossessed my veh...
# 35873  I have been a customer of citi cards for some ...
# 35874  I filed a previous complaint on XXXX/XXXX/XXXX...
# 35875  XXXX Bank XXXX is the substitutionary plaintif...
# 35876  yes i have a car loan out with ally.on my cred...
# 35877  I will need to send you the information becaus...
# 35878  I provide more supporting documents for the fo...
# 35879  I went into the branch of Chase Bank and reque...
# 35880  PNC banking institution used questionable tact...
# 35881  I made a charge with my Bank of America credit...
# 35882  Regions Mortgage is reported wage earner on cr...
# 35883  TDBAnk/ Target refused to accept credit counse...
# 35884  Where to start, I had mixed a debit card up wi...
# 35885  I purchased a brand new XXXX, side by side, re...
# 35886  After many months, or years, of having private...
# 35887  Complaint to CFPB regarding Chase letter offer...
# 35888  XXXX refuses to to refund my money which comes...
# 35889  Amazon said I would get {$50.00} if I applied ...
# 35890  My daughter took out a private student loan tw...
# 35891  In XX/XX/XXXX my mother and I purchased a XX/X...
# 35892  I have applied for loan modification with Bank...
# 35893  I wrote XXXX checks from my credit union check...
# 35894  I signed up for a Macy 's credit card in XXXX ...
# 35895  I took out a XXXX Chase credit card. The card ...
# 35896  On XXXX XXXX, 2016 at around XXXX, I submitted...
#
#                                       Company
# 0                        JPMORGAN CHASE & CO.
# 1                                U.S. BANCORP
# 2                        JPMORGAN CHASE & CO.
# 3      WELLS FARGO BANK, NATIONAL ASSOCIATION
# 4                         ALLY FINANCIAL INC.
# 5       BANK OF AMERICA, NATIONAL ASSOCIATION
# 6       BANK OF AMERICA, NATIONAL ASSOCIATION
# 7                         ALLY FINANCIAL INC.
# 8      WELLS FARGO BANK, NATIONAL ASSOCIATION
# 9                                U.S. BANCORP
# 10      BANK OF AMERICA, NATIONAL ASSOCIATION
# 11      BANK OF AMERICA, NATIONAL ASSOCIATION
# 12                       JPMORGAN CHASE & CO.
# 13      BANK OF AMERICA, NATIONAL ASSOCIATION
# 14                        ALLY FINANCIAL INC.
# 15     WELLS FARGO BANK, NATIONAL ASSOCIATION
# 16     WELLS FARGO BANK, NATIONAL ASSOCIATION
# 17     WELLS FARGO BANK, NATIONAL ASSOCIATION
# 18                       JPMORGAN CHASE & CO.
# 19     WELLS FARGO BANK, NATIONAL ASSOCIATION
# 20      BANK OF AMERICA, NATIONAL ASSOCIATION
# 21                       SUNTRUST BANKS, INC.
# 22      BANK OF AMERICA, NATIONAL ASSOCIATION
# 23                       JPMORGAN CHASE & CO.
# 24     WELLS FARGO BANK, NATIONAL ASSOCIATION
# 25      BANK OF AMERICA, NATIONAL ASSOCIATION
# 26     WELLS FARGO BANK, NATIONAL ASSOCIATION
# 27      BANK OF AMERICA, NATIONAL ASSOCIATION
# 28      BANK OF AMERICA, NATIONAL ASSOCIATION
# 29     WELLS FARGO BANK, NATIONAL ASSOCIATION
# ...                                       ...
# 35867  WELLS FARGO BANK, NATIONAL ASSOCIATION
# 35868  WELLS FARGO BANK, NATIONAL ASSOCIATION
# 35869                    JPMORGAN CHASE & CO.
# 35870  WELLS FARGO BANK, NATIONAL ASSOCIATION
# 35871                          CITIBANK, N.A.
# 35872  WELLS FARGO BANK, NATIONAL ASSOCIATION
# 35873                          CITIBANK, N.A.
# 35874  WELLS FARGO BANK, NATIONAL ASSOCIATION
# 35875                    JPMORGAN CHASE & CO.
# 35876                     ALLY FINANCIAL INC.
# 35877  WELLS FARGO BANK, NATIONAL ASSOCIATION
# 35878   BANK OF AMERICA, NATIONAL ASSOCIATION
# 35879                    JPMORGAN CHASE & CO.
# 35880                           PNC Bank N.A.
# 35881   BANK OF AMERICA, NATIONAL ASSOCIATION
# 35882                            REGIONS BANK
# 35883              TD BANK US HOLDING COMPANY
# 35884                    JPMORGAN CHASE & CO.
# 35885                          CITIBANK, N.A.
# 35886                    JPMORGAN CHASE & CO.
# 35887                    JPMORGAN CHASE & CO.
# 35888                    JPMORGAN CHASE & CO.
# 35889                    JPMORGAN CHASE & CO.
# 35890  WELLS FARGO BANK, NATIONAL ASSOCIATION
# 35891       FIFTH THIRD FINANCIAL CORPORATION
# 35892   BANK OF AMERICA, NATIONAL ASSOCIATION
# 35893                            REGIONS BANK
# 35894                          CITIBANK, N.A.
# 35895                    JPMORGAN CHASE & CO.
# 35896                     ALLY FINANCIAL INC.
#
# [35897 rows x 4 columns]

# %%
#But I'm more interested in Consumer_complaint_narrative against Bank of America
bank_of_america_file = df_new_sub[df_new_sub['Company']=='BANK OF AMERICA, NATIONAL ASSOCIATION']
bank_of_america_file.head()
# Out:
#    Date_received                  Product  \
# 5        3/31/17                 Mortgage
# 6         4/4/17  Bank account or service
# 10       3/31/17  Other financial service
# 11        4/5/17              Credit card
# 13       4/14/17  Bank account or service
#
#                          Consumer_complaint_narrative  \
# 5   In XX/XX/2005 I obtained a home equity mortgag...
# 6   I have been deprived of my income as Bank of A...
# 10  I bought a money order from XXXX XXXX to pay a...
# 11  My business debit cards were stolen from my ma...
# 13  I have opened the account of Bank of America a...
#
#                                   Company
# 5   BANK OF AMERICA, NATIONAL ASSOCIATION
# 6   BANK OF AMERICA, NATIONAL ASSOCIATION
# 10  BANK OF AMERICA, NATIONAL ASSOCIATION
# 11  BANK OF AMERICA, NATIONAL ASSOCIATION
# 13  BANK OF AMERICA, NATIONAL ASSOCIATION

# %%
# To extract the Consumer_complaint_narrative (documents)
documents = bank_of_america_file['Consumer_complaint_narrative']
documents.head()
# Out:
# 5     In XX/XX/2005 I obtained a home equity mortgag...
# 6     I have been deprived of my income as Bank of A...
# 10    I bought a money order from XXXX XXXX to pay a...
# 11    My business debit cards were stolen from my ma...
# 13    I have opened the account of Bank of America a...
# Name: Consumer_complaint_narrative, dtype: object

# %%
#Create a list of the documents
documents_list = list(documents)

# %%
#Number of the list
documents_list_num = len(documents_list)
documents_list_num
# Out:
# 7196

# %% [markdown]
# ### Feature Extraction

# %%
# the sklearn has a future extraction functionality that does the heavy lifting.
no_features = 1000

# %%
# NMF is able to use tf-idf
#tf-idf will scale down the impact of tokens that occur very frequently in a corpus that are empirically less informative

tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(documents)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# %%
# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(documents)
tf_feature_names = tf_vectorizer.get_feature_names()

# %% [markdown]
# ### Fitting both the NMF and LDA Algorithms on the Text Data.

# %%
# both algorithms cannot determine the number of topics, so the value must be set when running the algorithm
no_topics = 10

# %%
# NMF
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)
nmf
# Out:
# NMF(alpha=0.1, beta=1, eta=0.1, init='nndsvd', l1_ratio=0.5, max_iter=200,
#   n_components=10, nls_max_iter=2000, random_state=1, shuffle=False,
#   solver='cd', sparseness=None, tol=0.0001, verbose=0)

# %%
# LDA
lda = LatentDirichletAllocation(n_topics=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)
lda
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=50.0,
#              max_doc_update_iter=100, max_iter=5, mean_change_tol=0.001,
#              n_jobs=1, n_topics=10, perp_tol=0.1, random_state=0,
#              topic_word_prior=None, total_samples=1000000.0, verbose=0)

# %% [markdown]
# ### Create a Method to Display the Topics that Bank of America Customers Comlain About Most

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]])
)

# %%
no_top_words = 10

# %%
display_topics(nmf, tfidf_feature_names, no_top_words)
# Out:
# Topic 0:
# xxxx bank america 2015 00 2016 debt property received letter
# Topic 1:
# told called said did money phone asked time number xxxx
# Topic 2:
# xx xxxx 2016 2017 received 00 bankruptcy letter bofa report
# Topic 3:
# loan mortgage modification home bank america property foreclosure sale documents
# Topic 4:
# credit card report america reporting score cards bank charge debt
# Topic 5:
# 00 fee overdraft fees charged charge balance 35 charges account
# Topic 6:
# boa xxxx account cfpb funds years complaint transfer rep mortgage
# Topic 7:
# account bank america closed checking accounts open money opened close
# Topic 8:
# payment late payments pay month paid make mortgage 00 minimum
# Topic 9:
# check deposited deposit funds checks bank cash money cleared cashed

# %%
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# Topic 0:
# xxxx bank america sale property mortgage foreclosure loan documents home
# Topic 1:
# credit bank america report account card information reporting debt reported
# Topic 2:
# xxxx bank account america told check called did money xx
# Topic 3:
# card charges xxxx 00 charge bank credit transaction america debit
# Topic 4:
# loan bank america xxxx mortgage home modification time years told
# Topic 5:
# checks insurance 00 escrow paid taxes tax company bank pay
# Topic 6:
# xxxx xx bofa bank america 00 mortgage number complaint case
# Topic 7:
# payment 00 payments late balance pay credit paid month bank
# Topic 8:
# boa mortgage program bankruptcy hamp attorney payments appeal filed banks
# Topic 9:
# account bank xxxx 00 america fee fees checking charged money

# %% [markdown]
# ### Create Dataframe for Both Results and Compare The First 10 Topics

# %%
##Dataframe for the NMF Algorithm results
data_nmf = {
    'topics':['topic 0','topic 1','topic 2','topic 3','topic 4','topic 5','topic 6','topic 7','topic 8','topic 9'],
    'documents_nmf':['xxxx 2015 00 bank wells fargo received court debt letter',
                'account checking bank wells fargo accounts closed money opened funds',
                'xx xxxx 2016 2017 received 00 letter wf date dated',
                'wells mortgage fargo home modification foreclosure sale property documents house',
                'credit card report wells fargo reporting score debt balance cards',
            'payment payments late month mortgage monthly pay make paid escrow',
                '00 fees overdraft fee charged balance charge 35 charges transactions',
                'told said called did money asked phone bank time just',
                'check funds deposited deposit hold checks bank wells fargo cashed',
                'loan modification rate loans income years student payments refinance application']
    
}
df_topics_nmf = pd.DataFrame(data_nmf, columns=['topics','documents_nmf'])
df_topics_nmf
# Out:
#     topics                                      documents_nmf
# 0  topic 0  xxxx 2015 00 bank wells fargo received court d...
# 1  topic 1  account checking bank wells fargo accounts clo...
# 2  topic 2  xx xxxx 2016 2017 received 00 letter wf date d...
# 3  topic 3  wells mortgage fargo home modification foreclo...
# 4  topic 4  credit card report wells fargo reporting score...
# 5  topic 5  payment payments late month mortgage monthly p...
# 6  topic 6  00 fees overdraft fee charged balance charge 3...
# 7  topic 7  told said called did money asked phone bank ti...
# 8  topic 8  check funds deposited deposit hold checks bank...
# 9  topic 9  loan modification rate loans income years stud...

# %%
# Dataframe for the LDA Algorithm results
data_lda = {
    'topics':['topic 0','topic 1','topic 2','topic 3','topic 4','topic 5','topic 6','topic 7','topic 8','topic 9'],
    'documents_lda':['00 xxxx payment payments wells balance fargo month paid pay',
                'xxxx wells fargo mortgage loan property home bank documents foreclosure',
                'xxxx loan wells home fargo modification mortgage help time told',
                'xx xxxx sale short offer date house mortgage property received',
                'account fargo wells credit debt accounts report information reporting xxxx',
                'wf xxxx late fargo insurance wells fees services car pay',
                'xxxx wells fargo received letter sent number bank 2015 called',
                'account wells fargo bank check money xxxx funds 00 checking',
                'loan wells fargo credit xxxx mortgage rate payments years loans',
                'card xxxx told credit wells fargo did account called said']
    
}
df_topics_lda = pd.DataFrame(data_lda, columns=['topics','documents_lda'])
df_topics_lda
# Out:
#     topics                                      documents_lda
# 0  topic 0  00 xxxx payment payments wells balance fargo m...
# 1  topic 1  xxxx wells fargo mortgage loan property home b...
# 2  topic 2  xxxx loan wells home fargo modification mortga...
# 3  topic 3  xx xxxx sale short offer date house mortgage p...
# 4  topic 4  account fargo wells credit debt accounts repor...
# 5  topic 5  wf xxxx late fargo insurance wells fees servic...
# 6  topic 6  xxxx wells fargo received letter sent number b...
# 7  topic 7  account wells fargo bank check money xxxx fund...
# 8  topic 8  loan wells fargo credit xxxx mortgage rate pay...
# 9  topic 9  card xxxx told credit wells fargo did account ...

# %%
#Merging both dataframes
nmf_lda_merge = pd.merge(df_topics_nmf,df_topics_lda, on='topics')
nmf_lda_merge
# Out:
#     topics                                      documents_nmf  \
# 0  topic 0  xxxx 2015 00 bank wells fargo received court d...
# 1  topic 1  account checking bank wells fargo accounts clo...
# 2  topic 2  xx xxxx 2016 2017 received 00 letter wf date d...
# 3  topic 3  wells mortgage fargo home modification foreclo...
# 4  topic 4  credit card report wells fargo reporting score...
# 5  topic 5  payment payments late month mortgage monthly p...
# 6  topic 6  00 fees overdraft fee charged balance charge 3...
# 7  topic 7  told said called did money asked phone bank ti...
# 8  topic 8  check funds deposited deposit hold checks bank...
# 9  topic 9  loan modification rate loans income years stud...
#
#                                        documents_lda
# 0  00 xxxx payment payments wells balance fargo m...
# 1  xxxx wells fargo mortgage loan property home b...
# 2  xxxx loan wells home fargo modification mortga...
# 3  xx xxxx sale short offer date house mortgage p...
# 4  account fargo wells credit debt accounts repor...
# 5  wf xxxx late fargo insurance wells fees servic...
# 6  xxxx wells fargo received letter sent number b...
# 7  account wells fargo bank check money xxxx fund...
# 8  loan wells fargo credit xxxx mortgage rate pay...
# 9  card xxxx told credit wells fargo did account ...

# %% [markdown]
# ### To Discover Patterns in the Text Data I Applied the K-means Clustering Technique

# %% [markdown]
# Recall, with the tf-idf matrix above, I can run a K-means clustering algorithms to discover the hidden structure within the complaints data.
# Set initial number of clusters to 5.

# %%
#Import dependencies
from sklearn.cluster import KMeans

# %%
#Initialize number of clusters
num_clusters = 5

# %%
km = KMeans(n_clusters=num_clusters)

# %%
#recall
tfidf = tfidf_vectorizer.fit_transform(documents)

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

# %%
km.fit(tfidf_matrix)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clusters = km.labels_.tolist()

# %% [markdown]
# ### Create a Dataframe of Document and Cluster

# %%
topics = {'document':documents,'cluster':clusters}

frame = pd.DataFrame(topics, columns = ['document','cluster'])

frame.head()
# Out:
#                                              document  cluster
# 5   In XX/XX/2005 I obtained a home equity mortgag...        1
# 6   I have been deprived of my income as Bank of A...        0
# 10  I bought a money order from XXXX XXXX to pay a...        2
# 11  My business debit cards were stolen from my ma...        0
# 13  I have opened the account of Bank of America a...        0

# %%
#number of documents per cluster (clusters from 0 to 4)
frame['cluster'].value_counts()
# Out:
# 1    1890
# 0    1740
# 2    1541
# 4    1261
# 3     764
# Name: cluster, dtype: int64
